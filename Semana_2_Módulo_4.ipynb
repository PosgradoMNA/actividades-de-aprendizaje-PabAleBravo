# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-PabAleBravo/blob/main/Semana_2_M%C3%B3dulo_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias
import pandas as pd

# %% [markdown]
# # Examen 1

# %%
df=pd.DataFrame({'a':[11,21,31],'b':[21,22,23]})
df
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %%
df.iloc[0,1]
# Out:
# 21

# %%
df.iloc[1,0] #Este es el resultado correcto, por que pide, cuál es el código que da el segundo valor de la primera columna
# Out:
# 21

# %%
import pandas as banana #Si es funcional el código pero no es la forma estandarizada de ponerle el nombre a pandas, por lo que se puede dificultar el entendimiento

df=banana.DataFrame({'a':[11,21,31],'b':[21,22,23]})

df.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %% [markdown]
# # Examen 2

# %%
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})

# %%
df['a']==1
# Out:
# 0     True
# 1    False
# 2     True
# Name: a, dtype: bool

# %% [markdown]
# # Ejercicio

# %%
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})
df
# Out:
#    a  b
# 0  1  1
# 1  2  1
# 2  1  1

# %%
df['a'].unique() #Identificar cuales son los valores únicos del array
# Out:
# array([1, 2])

# %%
df[df['a']<2] #Sólo se muestran las columnas que son menores a 2
# Out:
#    a  b
# 0  1  1
# 2  1  1

# %%
filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
xlsx_path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%204/Datasets/TopSellingAlbums.xlsx'
df2 = pd.read_excel(xlsx_path)
df2.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %%
x = df[['Length']]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %%
x = df2[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %%
df2.iloc[0, 0]
# Out:
# 'Michael Jackson'

# %%
df2.iloc[1,2]
# Out:
# 1980

# %%
df2.loc[1, 'Released']
# Out:
# 1980
